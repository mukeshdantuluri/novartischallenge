# %%
# preprocesssing libraries
import pandas as pd
import numpy as np

# sklearn data manipulation libraries
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    plot_confusion_matrix,
    roc_auc_score,
    roc_curve,
    precision_recall_curve,
)

# lightgbm classifier
from lightgbm import LGBMClassifier

# Visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %%
location = "data/"

# %%
def read_data(loc, filename):
    df_in = pd.read_csv(loc + filename)
    return df_in

# %%
df_train = read_data(location, "Train.csv")
df_test = read_data(location, "Test.csv")
df_ss = read_data(location, "sample_submission.csv")

# %%
df_train.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_102659  04-JUL-04    0   36   34    2    1    5    6    1    6     1
# 1   CR_189752  18-JUL-17    1   37   37    0    0   11   17    1    6     1
# 2   CR_184637  15-MAR-17    0    3    2    3    5    1    0    2    3     1
# 3   CR_139071  13-FEB-09    0   33   32    2    1    7    1    1    6     1
# 4   CR_109335  13-APR-05    0   33   32    2    1    8    3    0    5     1
#
#    X_11  X_12  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0   174   1.0    92    29    36                 0
# 1   236   1.0   103   142    34                 1
# 2   174   1.0   110    93    34                 1
# 3   249   1.0    72    29    34                 1
# 4   174   0.0   112    29    43                 1

# %%
plt.figure(figsize=(16, 16))
sns.heatmap(df_train.corr())
plt.show()

# %%
## replace unknown data
def fill_unknown(df, col):
    df[col] = df[col].fillna(-1)
    df[col] = df[col].replace([np.inf, -np.inf], -1)
    df[col] = df[col].astype(int)
    return df

# %%
## parse date columns
def todate(df,col):
    df[col] = pd.to_datetime(df[col])
    return df

# %%
df_train = fill_unknown(df_train, "X_12")
df_test = fill_unknown(df_test, "X_12")
df_train = todate(df_train, "DATE")
df_test = todate(df_test, "DATE")

# %%
df_train["MULTIPLE_OFFENSE"].value_counts()
# Out:
# 1    22788
# 0     1068
# Name: MULTIPLE_OFFENSE, dtype: int64

# %%
X = df_train.drop(["INCIDENT_ID", "MULTIPLE_OFFENSE"], axis=1)
y = df_train[["MULTIPLE_OFFENSE"]]

test = df_test.drop(["INCIDENT_ID"], axis=1)
df_sub = df_test[["INCIDENT_ID"]]

# %%
## Adding features
def feature_engg(df):
    df["srday"] = df["DATE"].dt.day
    df["srmon"] = df["DATE"].dt.month

    ## binning days
    df.loc[df["srday"] <= 10, "day_buc"] = 1
    df.loc[(df["srday"] > 10) & (df["srday"] <= 20), "day_buc"] = 2
    df.loc[df["srday"] > 20, "day_buc"] = 3

    ## binning months into quarter
    df.loc[df["srmon"] <= 3, "quarter"] = 1
    df.loc[(df["srmon"] > 3) & (df["srmon"] <= 6), "quarter"] = 2
    df.loc[(df["srmon"] > 6) & (df["srmon"] <= 9), "quarter"] = 3
    df.loc[df["srmon"] > 9, "quarter"] = 4
    
    df['day_buc'] = df['day_buc'].astype(int)
    df['quarter'] = df['quarter'].astype(int)

    ## clubbing of low imp features in model
    #     df['combo'] = df['X_3'].astype(str) + df['X_6'].astype(str)
    #     df['combo'] = df['combo'].astype(int)

    ## drop correlated and low imp features
    df.drop(
        ["DATE", "X_1", "X_3", "X_6", "X_8", "srmon"],
        axis=1,
        inplace=True,
    )
    return df

# %%
X = feature_engg(X)
test = feature_engg(test)

X.head()
# Out:
#    X_2  X_4  X_5  X_7  X_9  X_10  X_11  X_12  X_13  X_14  X_15  srday  \
# 0   36    2    1    6    6     1   174     1    92    29    36      4
# 1   37    0    0   17    6     1   236     1   103   142    34     18
# 2    3    3    5    0    3     1   174     1   110    93    34     15
# 3   33    2    1    1    6     1   249     1    72    29    34     13
# 4   33    2    1    3    5     1   174     0   112    29    43     13
#
#    day_buc  quarter
# 0        1        3
# 1        2        3
# 2        2        1
# 3        2        1
# 4        2        2

# %%
X.dtypes
# Out:
# X_2        int64
# X_4        int64
# X_5        int64
# X_7        int64
# X_9        int64
# X_10       int64
# X_11       int64
# X_12       int64
# X_13       int64
# X_14       int64
# X_15       int64
# srday      int64
# day_buc    int64
# quarter    int64
# dtype: object

# %%
X.shape
# Out:
# (23856, 14)

# %%
cat_features_ids = [0, 2, 3, 4, 5, 6, 11, 12, 13]

# %%
def display_importances(feature_importance_df_):
    cols = (
        feature_importance_df_[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:40]
        .index
    )
    best_features = feature_importance_df_.loc[
        feature_importance_df_.feature.isin(cols)
    ]
    plt.figure(figsize=(8, 10))
    sns.barplot(
        x="importance",
        y="feature",
        data=best_features.sort_values(by="importance", ascending=False),
    )
    plt.title("LightGBM Features")
    plt.tight_layout()

# %%
feature_importance_df = pd.DataFrame()
oof_preds = np.zeros(X.shape[0])
i = 0
num_folds = 5

kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=1)


for n_fold, (train_ix, test_ix) in enumerate(kfold.split(X, y)):
    # select rows
    train_X, test_X = X.iloc[train_ix], X.iloc[test_ix]
    train_y, test_y = y.iloc[train_ix], y.iloc[test_ix]

    # summarize train and test composition
    train_0, train_1 = (
        len(train_y[train_y["MULTIPLE_OFFENSE"] == 0]),
        len(train_y[train_y["MULTIPLE_OFFENSE"] == 1]),
    )
    test_0, test_1 = (
        len(test_y[test_y["MULTIPLE_OFFENSE"] == 0]),
        len(test_y[test_y["MULTIPLE_OFFENSE"] == 1]),
    )
    print("===========================")
    print("Fold %2d" % (n_fold + 1))
    print("===========================")
    print("Train: 0=%d, 1=%d, Test: 0=%d, 1=%d" % (train_0, train_1, test_0, test_1))
    
    ## Lightgbm classifier
    clf = LGBMClassifier(
        is_unbalance=True, n_estimators=20000, learning_rate=0.02, silent=-1, verbose=-1
    )

    clf.fit(
        train_X,
        train_y,
        eval_set=[(train_X, train_y), (test_X, test_y)],
        eval_metric="auc",
        verbose=4000,
        categorical_feature=cat_features_ids
    )
    pred_split_probs = clf.predict_proba(test_X, num_iteration=clf.best_iteration_)[
        :, 1
    ]

    ##calculate precisin per each split
    precision, recall, thresholds = precision_recall_curve(test_y, pred_split_probs)

    print("train matrix")
    disp = plot_confusion_matrix(clf, train_X, train_y)
    plt.show()
    print("test matrix")
    disp = plot_confusion_matrix(clf, test_X, test_y)
    plt.show()

    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = train_X.columns
    fold_importance_df["importance"] = clf.feature_importances_
    fold_importance_df["fold"] = n_fold + 1
    feature_importance_df = pd.concat(
        [feature_importance_df, fold_importance_df], axis=0
    )
    print(
        "AUC : %.6f" % (roc_auc_score(test_y, oof_preds[test_ix]))
    )

    display_importances(feature_importance_df)
    plt.show()

    if i == 0:
        prec = precision
        rec = recall
        thres = thresholds
    else:
        prec = np.append(prec, precision)
        rec = np.append(rec, recall)
        thres = np.append(thres, thresholds)

    ## predict actual values
    pred_probs = clf.predict_proba(test, num_iteration=clf.best_iteration_)[:, 1]
    i = i + 1
    col_name = "MULTIPLE_OFFENSE" + str(i)
    df_sub[col_name] = pred_probs
# Out:
# ===========================
# Fold  1
# ===========================
# Train: 0=854, 1=18230, Test: 0=214, 1=4558
# [4000]	training's auc: 1	training's binary_logloss: 3.43996e-07	valid_1's auc: 1	valid_1's binary_logloss: 0.000133372
# [8000]	training's auc: 1	training's binary_logloss: 1.91305e-07	valid_1's auc: 1	valid_1's binary_logloss: 0.00011087
# [12000]	training's auc: 1	training's binary_logloss: 1.2465e-07	valid_1's auc: 1	valid_1's binary_logloss: 8.17619e-05
# [16000]	training's auc: 1	training's binary_logloss: 1.02837e-07	valid_1's auc: 1	valid_1's binary_logloss: 6.78398e-05
# [20000]	training's auc: 1	training's binary_logloss: 9.42051e-08	valid_1's auc: 1	valid_1's binary_logloss: 6.19864e-05
# train matrix
# test matrix
# AUC : 0.500000
# ===========================
# Fold  2
# ===========================
# Train: 0=854, 1=18231, Test: 0=214, 1=4557
# [4000]	training's auc: 1	training's binary_logloss: 3.76073e-07	valid_1's auc: 0.999999	valid_1's binary_logloss: 0.00121629
# [8000]	training's auc: 1	training's binary_logloss: 2.08602e-07	valid_1's auc: 0.999999	valid_1's binary_logloss: 0.0013694
# [12000]	training's auc: 1	training's binary_logloss: 1.5421e-07	valid_1's auc: 0.999999	valid_1's binary_logloss: 0.00142227
# [16000]	training's auc: 1	training's binary_logloss: 1.14602e-07	valid_1's auc: 0.999999	valid_1's binary_logloss: 0.00146712
# [20000]	training's auc: 1	training's binary_logloss: 9.7713e-08	valid_1's auc: 0.999999	valid_1's binary_logloss: 0.00147182
# train matrix
# test matrix
# AUC : 0.500000
# ===========================
# Fold  3
# ===========================
# Train: 0=854, 1=18231, Test: 0=214, 1=4557
# [4000]	training's auc: 1	training's binary_logloss: 3.52378e-07	valid_1's auc: 1	valid_1's binary_logloss: 0.000529349
# [8000]	training's auc: 1	training's binary_logloss: 1.85931e-07	valid_1's auc: 1	valid_1's binary_logloss: 0.000435376
# [12000]	training's auc: 1	training's binary_logloss: 1.31319e-07	valid_1's auc: 1	valid_1's binary_logloss: 0.000360906
# [16000]	training's auc: 1	training's binary_logloss: 1.04906e-07	valid_1's auc: 1	valid_1's binary_logloss: 0.000297018
# [20000]	training's auc: 1	training's binary_logloss: 9.57188e-08	valid_1's auc: 1	valid_1's binary_logloss: 0.000295175
# train matrix
# test matrix
# AUC : 0.500000
# ===========================
# Fold  4
# ===========================
# Train: 0=855, 1=18230, Test: 0=213, 1=4558
# [4000]	training's auc: 1	training's binary_logloss: 3.51282e-07	valid_1's auc: 0.999889	valid_1's binary_logloss: 0.00496571
# [8000]	training's auc: 1	training's binary_logloss: 1.73956e-07	valid_1's auc: 0.999892	valid_1's binary_logloss: 0.00509294
# [12000]	training's auc: 1	training's binary_logloss: 1.29289e-07	valid_1's auc: 0.999891	valid_1's binary_logloss: 0.00516937
# [16000]	training's auc: 1	training's binary_logloss: 1.03802e-07	valid_1's auc: 0.999894	valid_1's binary_logloss: 0.0051862
# [20000]	training's auc: 1	training's binary_logloss: 9.38157e-08	valid_1's auc: 0.999896	valid_1's binary_logloss: 0.00519708
# train matrix
# test matrix
# AUC : 0.500000
# ===========================
# Fold  5
# ===========================
# Train: 0=855, 1=18230, Test: 0=213, 1=4558
# [4000]	training's auc: 1	training's binary_logloss: 3.71837e-07	valid_1's auc: 0.999981	valid_1's binary_logloss: 0.00318093
# [8000]	training's auc: 1	training's binary_logloss: 2.24598e-07	valid_1's auc: 0.999979	valid_1's binary_logloss: 0.00334255
# [12000]	training's auc: 1	training's binary_logloss: 1.57924e-07	valid_1's auc: 0.999979	valid_1's binary_logloss: 0.00333121
# [16000]	training's auc: 1	training's binary_logloss: 1.28438e-07	valid_1's auc: 0.99998	valid_1's binary_logloss: 0.00332091
# [20000]	training's auc: 1	training's binary_logloss: 1.03497e-07	valid_1's auc: 0.999982	valid_1's binary_logloss: 0.00329938
# train matrix
# test matrix
# AUC : 0.500000

# %%
def get_metric_and_best_threshold_from_roc_curve(
    tpr, fpr, thresholds, num_pos_class, num_neg_class
):
    tp = tpr * num_pos_class
    tn = (1 - fpr) * num_neg_class
    acc = (tp + tn) / (num_pos_class + num_neg_class)

    best_threshold = thresholds[np.argmax(acc)]
    return np.amax(acc), best_threshold


def get_metric_and_best_threshold_from_pr_curve(
    precision, recall, thresholds, num_pos_class, num_neg_class
):
    tp = recall * num_pos_class
    fp = (tp / precision) - tp
    tn = num_neg_class - fp
    acc = (tp + tn) / (num_pos_class + num_neg_class)

    best_threshold = thresholds[np.argmax(acc)]
    return np.amax(acc), best_threshold

# %%
max_recall, best_thres = get_metric_and_best_threshold_from_pr_curve(
    prec, rec, thres, 1, 1
)
print("Max Recall: ", max_recall)
print("Best Threshold: ", best_thres)
# Out:
# Max Recall:  1.0
# Best Threshold:  0.8906260420140484

# %%
## Get average of predict proba and apply best threshold for binary classification
df_sub["MULTIPLE_OFFENSE_sum"] = (
    df_sub["MULTIPLE_OFFENSE1"]
    + df_sub["MULTIPLE_OFFENSE2"]
    + df_sub["MULTIPLE_OFFENSE3"]
    + df_sub["MULTIPLE_OFFENSE4"]
    + df_sub["MULTIPLE_OFFENSE5"]
)

df_sub["MULTIPLE_OFFENSE"] = df_sub["MULTIPLE_OFFENSE_sum"].apply(
    lambda x: 1 if x / 5 >= best_thres else 0
)

# %%
df_finalsub = df_sub[["INCIDENT_ID", "MULTIPLE_OFFENSE"]]
df_finalsub["MULTIPLE_OFFENSE"].value_counts()
# Out:
# 1    15167
# 0      736
# Name: MULTIPLE_OFFENSE, dtype: int64

# %%
df_finalsub.to_csv("highest_submission.csv", index=False)
